# %% [markdown]
# 1'#Supervised learning:Dataset is labelled,predict,linear regression, decision tree,support vector machine,
# neural network(supervised learning)
#
# #Unsupervised learning-: deals with un labelled data,clustering algorithms to group data together
# k-means clustering,hierachal clustering,pca(principle component analysis)
#
# #Reinforcement learning
#
#
# #problem formulation
# Define the problem
# Classification task
# regression analysis
# clustering
# anomaly detection recommmendation

# %% [markdown]
# 2;-Gather data
# 3-split data
#
# DATA TYPES
#  NUMERICAL
#  CATEGORICAL
#  ORDINAL

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

#ML REGRESSION
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

#ignore warnings
#import warnings
#warnings.filterwarnings('ignore')

#Control display
#sns.set(style="darkgrid", rc={"axes.facecolor": "#CAFIDE"})

# Rest of your code
#pd.options.display.max_columns = 50
df = pd.read_csv("./heart.csv")
print(df.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
#Pipo with heart diseases
df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#Percentage of male and female
count_female = len(df[df.sex==0])
count_male = len(df[df.sex==1])

#output
print('percentage of female:{:.2f}%'.format(count_female/len(df.sex)*100))
print('percentage of male:{:.2f}%'.format(count_male/len(df.sex)*100))
# Out:
# percentage of female:30.44%
# percentage of male:69.56%

# %%
df.groupby('target').mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.569138  0.827655  0.482966  134.106212  251.292585  0.164329
# 1       52.408745  0.570342  1.378327  129.245247  240.979087  0.134981
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.456914  139.130261  0.549098  1.600200  1.166333  1.158317  2.539078
# 1       0.598859  158.585551  0.134981  0.569962  1.593156  0.370722  2.119772

# %%
#bar graph
pd.crosstab(df.age, df.target).plot(kind='bar')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Mboowa z graph')
plt.show()

# %%
#bar graph
pd.crosstab(df.age, df.target).plot(kind='bar',color=['blue', 'red'],figsize=(20,6))
plt.legend(['Have Disease','No disease'])
plt.ylabel('Frequency')
plt.title('Mboowa z graph')
plt.xticks(rotation=0)
plt.show()

# %%
df.columns
sns.scatterplot(x='target',y='thalach',data=df)

plt.ylabel('Frequency')
plt.title('Mboowa z graph')

plt.show()

# %%
# Create scatter plot
# df.columns
# plt.scatter(Age, Chol, c=df['target'], cmap='coolwarm')
# plt.xlabel('Age')
# plt.ylabel('Cholesterol')
# plt.title('Scatter Plot: Age vs Cholesterol')
# plt.colorbar(label='Target')
# plt.show()

# %%
#CREATING A MODEL FOR LOGISTRIC REGRESSION
# y=df.target.value
# x_data=df.drop(['target'],axis=1)

# %%
#NORMALIZE THE DATA SPLIT DATA 4 TRAINING


# X=(x_data-np.min(x_data))/np.max(x_data)-np.min(x_data)

# %%
#80-train  20-_test_split
#x_data, y_data

# %%
#TRANSPOSE MATRICES
# x_train=x_train.T
# y_train=y_train.T
# y_test=y_test.T
# x_train=x_train.T

# %%
#DECISION TREES

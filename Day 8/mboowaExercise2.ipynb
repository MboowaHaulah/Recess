# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("./crime.csv")
print(df.head())

#Before cleaning my dataset had duplicates, empty cells and wrong data but after cleaning there is nothing
#am analyzing since it has inconsistent data
# Out:
#   Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0        NaN                    NaN            NaN                  NaN
# 1        NaN                    NaN     CasesTotal  Cases under Inquiry
# 2      S/No.  CASE/CRIME INCIDENCES              1                    2
# 3        NaN              HOMICIDES            NaN                  NaN
# 4          1   Death  (by shooting)            190                  117
#
#          Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# 0               NaN                   NaN                        NaN
# 1  Not Detected/NPW  Cases taken to court  Cases submitted toDPP/RSA
# 2                 3                     4                          5
# 3               NaN                   NaN                        NaN
# 4                29                    44                         74
#
#                Unnamed: 7             Unnamed: 8       Unnamed: 9  ...  \
# ...

# %%
df=df.dropna(inplace=True)
#i had to drop inorder to have a clean data set since some cells were empty

# %%
df = pd.read_csv('parliament.csv', encoding='latin1')

#i had to use another encoding since the normal encoding couldnt work and there was an error

# %% [markdown]
# EMPTY()

# %%
import pandas as pd

df = pd.read_csv('parliament.csv', encoding='latin1')


df = df.dropna()

print(df.to_string())
# Out:
# Empty DataFrame
# ...

# %%
#check for nulls
import pandas as pd

df = pd.read_csv('parliament.csv', encoding='latin1')
df.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 65        439
# Unnamed: 62        439
# Unnamed: 64        439
# Unnamed: 61        439
# Unnamed: 66        439
#                   ...
# Political Party      2
# Profession           1
# Name of M.P          0
# Constituency         0
# No.                  0
# Length: 87, dtype: int64

# %%
#fillna()
#Fillna
import pandas as pd
df = pd.read_csv('parliament.csv', encoding='latin1')

df_filled = df.fillna('NA')
#I had to fill in NA since we had some empty cells

# %%
import pandas as pd

df = pd.read_csv('parliament.csv', encoding='cp1252')



df = df.dropna()

print(df.to_string())
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# WRONG FORMAT

# %%
#WRONG FORMAT
df.at[5,'Timestamp']='14/07/2023 '
df
# Out:
#    No. Name of M.P District Constituency Political Party Profession  \
# 5  NaN         NaN      NaN          NaN             NaN        NaN
#
#   Marital status Phone number Date of Birth P.L.E School  ... Unnamed: 78  \
# 5            NaN          NaN           NaN          NaN  ...         NaN
#
#   Unnamed: 79 Unnamed: 80 Unnamed: 81 Unnamed: 82 Unnamed: 83 Unnamed: 84  \
# 5         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 85 Unnamed: 86    Timestamp
# 5         NaN         NaN  14/07/2023
#
# [1 rows x 88 columns]

# %% [markdown]
# WRONG DATA

# %%
import pandas as pd

df = pd.read_csv('parliament.csv', encoding='latin1')
for x in df.index:
    if df.loc[x,"District"]=="None":
        df.drop(x,inplace=True)
        df

# %%
df
# Out:
#      No.                      Name of M.P   District  \
# 0      1               Aadroa Alex Onzima        NaN
# 1      2                    Ababiku Jesca   Adjumani
# 2      3  ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 3      4                      ABALA DAVID      Ngora
# 4      5             ABBAS AGABA MUGISHA    Kamwenge
# ..   ...                              ...        ...
# 434  435            Wekomba Nambozo Sarah  Bulambuli
# 435  436         Werikhe Kafabusa Michael      Mbale
# 436  437                    Woboya Vicent    Sironko
# 437  438               Yaguma Wilberforce    Mbarara
# 438  439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio             NaN    Administrator
# 1    District Woman Representative             NRM          Teacher
# 2               ERUTE COUNTY NORTH             FDC           Farmer
# ...

# %% [markdown]
# DUPLICATES

# %%
import pandas as pd

df = pd.read_csv('parliament.csv', encoding='latin1')
df.drop_duplicates(inplace=True)
print(df.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# Length: 439, dtype: bool

# %% [markdown]
# PLOTING

# %%
df['No.'].plot(kind='hist')
plt.xlabel('No.')
plt.ylabel('Frequency')
plt.title('Mboowa z histogram')
plt.show()

# %%
df['No.'].plot(kind='pie')

plt.title('Mboowa z piechart')
plt.show()

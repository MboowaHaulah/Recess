# %%
#1.Write a Pandas program to compare the elements of two Pandas series. 
#Sample Series [4,65,436,3,9], [7,0,3,897,9]
import pandas as pd

series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

compare= series1 == series2
print(compare)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
#2.Write a Pandas program to add, subtract, multiply and divide two Pandas series. 
#Sample Series: [2,4,6,8,14], [1,3,5,7,9]
import pandas as pd

series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

addition = series1 + series2
subtraction = series1 - series2
multiplication = series1 * series2
division = series1 / series2

print("Addition:")
print(addition)
print("Subtraction:")
print(subtraction)
print("Multiplication:")
print(multiplication)
print("Division:")
print(division)
# Out:
# Addition:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
# Subtraction:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
# Multiplication:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
# Division:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %%
# 3.Write a Pandas program to convert a dictionary to a Pandas series. 
# Sample dictionary: dictionary1 = {‘Josh’: 24, ‘Sam’: 36, ‘Peace’: 19, ‘Charles’: 65, ‘Tom’: 44}
import pandas as pd

dict = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}
series = pd.Series(dict)
print(series)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %%
#4.Write a Pandas program to convert a given series to an array.
#Sample series: [‘Love’, 800, ‘Joy’, 789.9, ‘Peace’, True]
import pandas as pd
import numpy as np

series = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])
array = np.array(series)
print(array)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
#5.Write a Pandas program to display the most frequent value in the given series and replace everything else as ‘Other’ in the series. 
#(Use the ‘HomeTeamGoals’ column in the dataset provided)
import pandas as pd

cup = pd.read_csv('cup.csv')  

# Find the most frequent value
most_frequent_value = cup['HomeTeamGoals'].mode()[0]

# Replace everything else as 'Other'
cup['HomeTeamGoals'] = cup['HomeTeamGoals'].apply(lambda x: most_frequent_value if x == most_frequent_value else 'Other')

print(cup['HomeTeamGoals'])
# Out:
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object

# %%
#EXERCISE 2
#DATAFRAMES
#1.Write a Pandas program to read the given csv file.
import pandas as pd

df= pd.read_csv('cup.csv')

# %%
#2.Write a Pandas program to get the first 7 rows of your data frame.
df.head(7)
# Out:
#    Year      Date  Time    HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan           Egypt            1.0
# 1  1957  10-Feb-57   NaN  Ethiopia    South Africa            NaN
# 2  1957  16-Feb-57   NaN     Egypt        Ethiopia            4.0
# 3  1959  22-May-59   NaN      Egypt       Ethiopia            4.0
# 4  1959  25-May-59   NaN     Sudan        Ethiopia            1.0
# 5  1959  29-May-59   NaN      Egypt          Sudan            2.0
# 6  1962  14-Jan-62   NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %%
#3.Write a Pandas program to select the ‘HomeTeam’, ‘AwayTeam’, ‘HomeTeamGoals’ and ‘AwayTeamGoals’ columns from your data frame.
selected_columns = cup[['HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals']]
print(selected_columns)
# Out:
#         HomeTeam       AwayTeam HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt           1.0            2.0
# 1      Ethiopia    South Africa         Other            NaN
# 2         Egypt        Ethiopia         Other            0.0
# 3          Egypt       Ethiopia         Other            0.0
# 4         Sudan        Ethiopia           1.0            0.0
# ..           ...            ...           ...            ...
# 617  Madagascar         Tunisia         Other            3.0
# 618     Senegal         Tunisia           1.0            0.0
# 619     Algeria         Nigeria         Other            1.0
# 620     Tunisia         Nigeria         Other            1.0
# 621     Senegal         Algeria         Other            1.0
#
# [622 rows x 4 columns]

# %%
#4.Write a Pandas program to select the rows where Egypt appears.
egypt_rows = cup[cup['HomeTeam'].str.contains('Egypt') | cup['AwayTeam'].str.contains('Egypt')]
print(egypt_rows)
# Out:
#      Year                         Date   Time  HomeTeam       AwayTeam  \
# 0    1957                     10-Feb-57    NaN   Sudan           Egypt
# 2    1957                     16-Feb-57    NaN   Egypt        Ethiopia
# 3    1959                     22-May-59    NaN    Egypt       Ethiopia
# 5    1959                     29-May-59    NaN    Egypt          Sudan
# 7    1962                     18-Jan-62    NaN    Egypt         Uganda
# ..    ...                           ...    ...      ...            ...
# 569  2017  5 February 2017 (2017-02-05)  20:00   Egypt        Cameroon
# 570  2019     21 June 2019 (2019-06-21)  22:00   Egypt        Zimbabwe
# 573  2019     26 June 2019 (2019-06-26)  22:00   Egypt        DR Congo
# 574  2019     30 June 2019 (2019-06-30)  21:00  Uganda           Egypt
# 609  2019      6 July 2019 (2019-07-06)  21:00   Egypt    South Africa
#
#     HomeTeamGoals  AwayTeamGoals             Stage SpecialWinConditions  \
# ...

# %%
#5.Write a Pandas program to count the number of rows and columns of your data frame.
num_rows, num_cols = df.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 622
# Number of columns: 12

# %%
df.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
#6.Write a Pandas program to select the rows where the ‘Attendance’ is missing.
missing_attendance = df[cup['Attendance'].isnull()]
print(missing_attendance)
# Out:
#      Year                         Date   Time        HomeTeam       AwayTeam  \
# 1    1957                     10-Feb-57    NaN      Ethiopia    South Africa
# 8    1962                     20-Jan-62    NaN       Tunisia          Uganda
# 9    1962                     21-Jan-62    NaN      Ethiopia           Egypt
# 10   1963                     24-Nov-63    NaN         Ghana         Tunisia
# 11   1963                     26-Nov-63    NaN         Ghana        Ethiopia
# ..    ...                           ...    ...            ...            ...
# 565  2017  29 January 2017 (2017-01-29)  20:00         Egypt         Morocco
# 566  2017  1 February 2017 (2017-02-01)  20:00  Burkina Faso           Egypt
# 567  2017  2 February 2017 (2017-02-02)  20:00      Cameroon           Ghana
# 568  2017  4 February 2017 (2017-02-04)  20:00  Burkina Faso           Ghana
# 569  2017  5 February 2017 (2017-02-05)  20:00         Egypt        Cameroon
#
# ...

# %%
print(df.to_string())
# Out:
#      Year                         Date           Time            HomeTeam              AwayTeam  HomeTeamGoals  AwayTeamGoals                 Stage                                      SpecialWinConditions                         Stadium                  City  Attendance
# 0    1957                     10-Feb-57            NaN             Sudan                  Egypt            1.0            2.0            Semifinals                                                       NaN               Municipal Stadium              Khartoum     30000.0
# 1    1957                     10-Feb-57            NaN          Ethiopia           South Africa            NaN            NaN            Semifinals      Ethiopia  wins due to disqualification of other team                             NaN                   NaN         NaN
# ...

# %%
#7.Write a Pandas program to select the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.


cup['HomeTeamGoals'] = pd.to_numeric(cup['HomeTeamGoals'], errors='coerce')
selected_rows = df[(cup['HomeTeamGoals'] >= 3) & (cup['HomeTeamGoals'] <= 6)]
print(selected_rows)
# Out:
# Empty DataFrame
# Columns: [Year, Date , Time , HomeTeam, AwayTeam, HomeTeamGoals, AwayTeamGoals, Stage, SpecialWinConditions, Stadium, City, Attendance]
# Index: []

# %%
#8.Write a Pandas program to change the “AwayTeamGoals” in the 3rd row to 10.
cup.loc[2, 'AwayTeamGoals'] = 10
print(cup)
# Out:
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %%
#9.Write a Pandas program to sort the DataFrame first by ‘HomeTeam’ in ascending order, then by ‘HomeTeamScores’
# in descending order.
sorted_df = cup.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])
print(sorted_df)
# Out:
#      Year                         Date           Time    HomeTeam  \
# 133  1980                     13-Mar-80            NaN   Algeria
# 148  1982                      7-Mar-82            NaN   Algeria
# 193  1988                     19-Mar-88            NaN   Algeria
# 220  1990                     16-Mar-90          16:00   Algeria
# 229  1992                     17-Jan-92            NaN   Algeria
# ..    ...                           ...            ...        ...
# 521  2012                     12-Feb-12  20:30[note 1]    Zambia
# 398  2004                     25-Jan-04          16:30  Zimbabwe
# 437  2006                     23-Jan-06          20:00  Zimbabwe
# 549  2017  23 January 2017 (2017-01-23)          20:00  Zimbabwe
# 575  2019     30 June 2019 (2019-06-30)          21:00  Zimbabwe
#
#          AwayTeam  HomeTeamGoals  AwayTeamGoals    Stage  \
# 133       Morocco            1.0            0.0  Group B
# 148        Zambia            1.0            0.0  Group B
# ...

# %%
#10.Write a Pandas program to get list from DataFrame column headers.
column_headers = cup.columns.tolist()
print(column_headers)
# Out:
# ['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %%
#11.Write a Pandas program to append a column of your choice to your DataFrame.
import pandas as pd

# Creating a sample DataFrame
cup = pd.DataFrame({
    'HomeTeam': ['Team A', 'Team B', 'Team C', 'Team D'],
    'HomeTeamGoals': [2, 3, 1, 4],
})

# Creating a list of Away team countries
away_teams = ['France', 'Germany', 'Spain', 'Brazil']

# Appending the 'AwayTeam' column to the DataFrame
cup['AwayTeam'] = away_teams

# Displaying the updated DataFrame
print(cup)
# Out:
#   HomeTeam  HomeTeamGoals AwayTeam
# 0   Team A              2   France
# 1   Team B              3  Germany
# 2   Team C              1    Spain
# 3   Team D              4   Brazil

# %%
#12.Write a Pandas program to add 2 rows to your DataFrame.
import pandas as pd

# Create a DataFrame 'cup' with some initial data
cup = pd.DataFrame({
    'HomeTeam': ['Team X', 'Team Y'],
    'AwayTeam': ['Team Z', 'Team W'],
    'HomeTeamGoals': [3, 1],
    'AwayTeamGoals': [2, 0]
})

# Define new rows to be added
new_rows = [{'HomeTeam': 'Team A', 'AwayTeam': 'Team B', 'HomeTeamGoals': 2, 'AwayTeamGoals': 1},
            {'HomeTeam': 'Team C', 'AwayTeam': 'Team D', 'HomeTeamGoals': 0, 'AwayTeamGoals': 2}]

# Append the new rows to the DataFrame
df = pd.concat([cup, pd.DataFrame(new_rows)], ignore_index=True)

# Print the updated DataFrame
print(df)
# Out:
#   HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0   Team X   Team Z              3              2
# 1   Team Y   Team W              1              0
# 2   Team A   Team B              2              1
# 3   Team C   Team D              0              2

# %%
#13.Write a Pandas program to change the country ‘Uganda’ to ‘China’ in the ‘AwayTeam’ column of the DataFrame.
cup.loc[cup['AwayTeam'] == 'Uganda', 'AwayTeam'] = 'China'
print(cup)
# Out:
#   HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0   Team X   Team Z              3              2
# 1   Team Y   Team W              1              0

# %%
#14.Write a Pandas program to reset index in your DataFrame.
df = cup.reset_index(drop=True)
print(cup)
# Out:
#   HomeTeam AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0   Team X   Team Z              3              2
# 1   Team Y   Team W              1              0

# %%
#15.Write a Pandas program to check whether the ‘Stadium’ column is present in your DataFrame or not.
if 'Stadium' in cup.columns:
    print("The 'Stadium' column is present in the DataFrame.")
else:
    print("The 'Stadium' column is not present in the DataFrame.")
# Out:
# The 'Stadium' column is not present in the DataFrame.

# %%
#16.Write a Pandas program to convert the datatype of the ‘AwayTeamGoals’. (int to float)
cup['AwayTeamGoals'] = cup['AwayTeamGoals'].astype(float)
print(cup.dtypes)
# Out:
# HomeTeam          object
# AwayTeam          object
# HomeTeamGoals      int64
# AwayTeamGoals    float64
# dtype: object

# %%
#17.Write a Pandas program to remove the last 10 rows from your DataFrame.
cup = cup[:-10]
print(cup)
# Out:
# Empty DataFrame
# Columns: [HomeTeam, AwayTeam, HomeTeamGoals, AwayTeamGoals]
# Index: []

# %%
#18.Write a Pandas program to iterate over rows in your DataFrame.
for index, row in cup.iterrows():
    print(row['HomeTeam'], row['AwayTeam'])

# %%
#19.Write a Pandas program to change the order of your DataFrame columns.
import pandas as pd
new_column_order = ['AwayTeam', 'AwayTeamGoals', 'HomeTeam', 'HomeTeamGoals']
df = df[new_column_order]
print(df)

# # Creating a sample DataFrame
# df = pd.DataFrame({
#     'HomeTeam': ['Team A', 'Team B', 'Team C'],
#     'AwayTeam': ['Team X', 'Team Y', 'Team Z'],
#     'HomeTeamGoals': [2, 3, 1],
#     'AwayTeamGoals': [1, 2, 0]
# })

# print("Original DataFrame:")
# print(df)

# # Define the new column order
# new_column_order = ['AwayTeam', 'AwayTeamGoals', 'HomeTeam', 'HomeTeamGoals']

# # Reorder the columns
# df = df[new_column_order]

# print("\nDataFrame with Changed Column Order:")
# print(df)
# Out:
#   AwayTeam  AwayTeamGoals HomeTeam  HomeTeamGoals
# 0   Team Z              2   Team X              3
# 1   Team W              0   Team Y              1
